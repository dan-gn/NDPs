# %%
import os
os.cpu_count()
# Out:
# 2

# %%
# !git clone https://github.com/dan-gn/NDPs.git
# %cd NDPs/
# Out:
# Cloning into 'NDPs'...
# remote: Enumerating objects: 248, done.
# remote: Counting objects: 100% (248/248), done.
# remote: Compressing objects: 100% (121/121), done.
# remote: Total 248 (delta 124), reused 211 (delta 94), pack-reused 0 (from 0)
# Receiving objects: 100% (248/248), 96.03 KiB | 833.00 KiB/s, done.
# Resolving deltas: 100% (124/124), done.
# /content/NDPs

# %%
# !pip install cma
# !pip install swig
# !pip install "gymnasium[box2d]"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.3/328.3 kB 8.5 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 31.9 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 45.0 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 84.6 MB/s eta 0:00:00:00:0100:01
# ...

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !python Experiments/initial_test.py
# Out:
# This is an initial test of the NDP!
# -------------------------------------
# Task
# -------------------------------------
# Name = Acrobot-v1
# Target value = 225
# -------------------------------------
#
#
# -------------------------------------
# NDP
# -------------------------------------
# Graph
# Node internal state size = 5
# Number of inputs = 6
# Number of outputs = 3
# -------------------------------------
# MLP Parameters
# Graph Cellular Automata = 60
# Replication Model = 36
# Weight Prediction Model = 61
# Total = 157
# -------------------------------------
#
#
# Starting optimisation!
# Running on Google Colab
# Number of cores 1
# Initialising population...
